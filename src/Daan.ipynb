# %%
# Machine Learning Data Exploration
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/daan/Desktop/Nova IMS/Machine Learning/Project/project_data/train_data.csv', sep= ",")
df
# Out:
# /var/folders/cb/8gnf1rrd7914vbmqtgrt2mmm0000gn/T/ipykernel_4864/1559504511.py:1: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/daan/Desktop/Nova IMS/Machine Learning/Project/project_data/train_data.csv', sep= ",")
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# 0         2019-12-30           31.0                              N
# 1         2019-08-30           46.0                              N
# 2         2019-12-06           40.0                              N
# 3                NaN            NaN                            NaN
# 4         2019-12-30           61.0                              N
# ...              ...            ...                            ...
# 593466           NaN            NaN                            NaN
# 593467    2022-12-13           72.0                              N
# 593468           NaN            NaN                            NaN
# ...

# %%
df.shape
# Out:
# (593471, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593471 entries, 0 to 593470
# Data columns (total 33 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Accident Date                       570337 non-null  object
#  1   Age at Injury                       574026 non-null  float64
#  2   Alternative Dispute Resolution      574026 non-null  object
#  3   Assembly Date                       593471 non-null  object
#  4   Attorney/Representative             574026 non-null  object
#  5   Average Weekly Wage                 545375 non-null  float64
#  6   Birth Year                          544948 non-null  float64
#  7   C-2 Date                            559466 non-null  object
#  8   C-3 Date                            187245 non-null  object
#  9   Carrier Name                        574026 non-null  object
#  10  Carrier Type                        574026 non-null  object
# ...

# %%
list(df["WCB Decision"].drop_duplicates())
# Out:
# ['Not Work Related', nan]

# %%
df_2 = df[["WCB Decision", "WCIO Cause of Injury Code", "WCIO Cause of Injury Description","Accident Date"]]
df_2
# Out:
#             WCB Decision  WCIO Cause of Injury Code  \
# 0       Not Work Related                       27.0
# 1       Not Work Related                       97.0
# 2       Not Work Related                       79.0
# 3                    NaN                        NaN
# 4       Not Work Related                       16.0
# ...                  ...                        ...
# 593466               NaN                        NaN
# 593467  Not Work Related                       25.0
# 593468               NaN                        NaN
# 593469               NaN                        NaN
# 593470               NaN                        NaN
#
#         WCIO Cause of Injury Description Accident Date
# 0           FROM LIQUID OR GREASE SPILLS    2019-12-30
# 1                      REPETITIVE MOTION    2019-08-30
# 2         OBJECT BEING LIFTED OR HANDLED    2019-12-06
# 3                                    NaN           NaN
# 4        HAND TOOL, UTENSIL; NOT POWERED    2019-12-30
# ...

# %%
df_with_NaN = df_2[df_2["WCB Decision"] != "Not Work Related"]
df_with_NaN
df_with_NaN.drop_duplicates()
# Out:
#   WCB Decision  WCIO Cause of Injury Code WCIO Cause of Injury Description  \
# 3          NaN                        NaN                              NaN
#
#   Accident Date
# 3           NaN

# %%
df_without_NaN = df_2.dropna
df_without_NaN()
# Out:
#             WCB Decision  WCIO Cause of Injury Code  \
# 0       Not Work Related                       27.0
# 1       Not Work Related                       97.0
# 2       Not Work Related                       79.0
# 4       Not Work Related                       16.0
# 5       Not Work Related                       31.0
# ...                  ...                        ...
# 593451  Not Work Related                       45.0
# 593455  Not Work Related                       74.0
# 593456  Not Work Related                       98.0
# 593457  Not Work Related                       59.0
# 593467  Not Work Related                       25.0
#
#                    WCIO Cause of Injury Description Accident Date
# 0                      FROM LIQUID OR GREASE SPILLS    2019-12-30
# 1                                 REPETITIVE MOTION    2019-08-30
# 2                    OBJECT BEING LIFTED OR HANDLED    2019-12-06
# 4                   HAND TOOL, UTENSIL; NOT POWERED    2019-12-30
# ...
